# %% [markdown]
# # What this notebook does?
#
# Problem: I don't have my team selected for fantasy premier league
# Solution: Use data from [vaastav](https://github.com/vaastav/Fantasy-Premier-League) and method from [knapsack](https://medium.com/@kangeugine/fantasy-football-as-a-data-scientist-part-2-knapsack-problem-6b7083955e93)

# %% [markdown]
# # Load

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pulp import *

sns.set(style="white")
# %matplotlib inline

# %% [markdown]
# # Data

# %%
cleaned_players_data = pd.read_csv("/Users/eugine_kang/Documents/hobby/Fantasy-Premier-League/data/2022-23/cleaned_players.csv")
players_raw_data = pd.read_csv("/Users/eugine_kang/Documents/hobby/Fantasy-Premier-League/data/2022-23/players_raw.csv")
teams_data = pd.read_csv("/Users/eugine_kang/Documents/hobby/Fantasy-Premier-League/data/2022-23/teams.csv")[['code', 'name']]
teams_data.columns = ['team_code', 'team_name']
_data = pd.merge(cleaned_players_data, 
    players_raw_data[['first_name', 'second_name', 'team_code']], 
    how="left", 
    on=['first_name', 'second_name']
)
data = pd.merge(_data, teams_data, how="left", on=["team_code"])

# %% [markdown]
# # Squad Selection
# - 100 pounds spending limit
# - 15 players
# - 2 GK
# - 5 DEF
# - 5 MID
# - 3 STR
# - Select a maximum of 3 players from a single team

# %%
n = data.shape[0]
player = [str(i) for i in range(n)]
point = {str(i): float(data['total_points'][i]) for i in range(n)} 
cost = {str(i): float(data['now_cost'][i]) for i in range(n)}
gk = {str(i): 1 if data['element_type'][i] == 'GK' else 0 for i in range(n)}
defe = {str(i): 1 if data['element_type'][i] == 'DEF' else 0 for i in range(n)}
mid = {str(i): 1 if data['element_type'][i] == 'MID' else 0 for i in range(n)}
stri = {str(i): 1 if data['element_type'][i] == 'FWD' else 0 for i in range(n)}
xi = {str(i): 1 for i in range(n)}

# %%
prob = LpProblem("Fantasy_Football",LpMaximize)
player_vars = LpVariable.dicts("Players",player,0,1,LpBinary)

# %%
# objective function
prob += lpSum([point[i]*player_vars[i] for i in player]), "Total Cost"

# constraint
prob += lpSum([player_vars[i] for i in player]) == 15, "Total 11 Players"
prob += lpSum([cost[i] * player_vars[i] for i in player]) <= 1000, "Total Cost"
prob += lpSum([gk[i] * player_vars[i] for i in player]) == 2, "2 GK"
prob += lpSum([defe[i] * player_vars[i] for i in player]) == 5, "5 DEK"
prob += lpSum([mid[i] * player_vars[i] for i in player]) == 5, "5 MID"
prob += lpSum([stri[i] * player_vars[i] for i in player]) == 3, "3 FWD"

# team constraint
for j in data['team_name'].unique():
    team = {str(i): 1 if data['team_name'][i] == j else 0 for i in range(n)}
    prob += lpSum([team[i] * player_vars[i] for i in player]) <= 3, f"Max 3 players from {j}"

# %%
# solve
status = prob.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.8
# Build Date: May  6 2022
#
# command line - cbc /var/folders/xx/ndggzzd56zdfznymtxfg5q5w0000gn/T/d0e984c3cbf5489ca44d4659ea61bfb1-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/xx/ndggzzd56zdfznymtxfg5q5w0000gn/T/d0e984c3cbf5489ca44d4659ea61bfb1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 31 COLUMNS
# At line 3546 RHS
# At line 3573 BOUNDS
# At line 4095 ENDATA
# Problem MODEL has 26 rows, 521 columns and 2084 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 2491.88 - 0.00 seconds
# Cgl0004I processed model has 26 rows, 471 columns (471 integer (452 of which binary)) and 1884 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.25
# Cbc0038I Solution found of -2482
# Cbc0038I Cleaned solution of -2482
# Cbc0038I Before mini branch and bound, 469 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 26 rows 471 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of -2483.89
# Cbc0038I Reduced cost fixing fixed 446 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.03199 (2) obj. -2483.89 iterations 5
# Cbc0038I Pass   2: suminf.    0.16667 (2) obj. -2491.83 iterations 4
# Cbc0038I Pass   3: suminf.    0.31059 (4) obj. -2483.89 iterations 9
# Cbc0038I Pass   4: suminf.    0.31059 (4) obj. -2483.89 iterations 0
# Cbc0038I Pass   5: suminf.    0.33333 (2) obj. -2489.67 iterations 5
# Cbc0038I Pass   6: suminf.    0.23538 (2) obj. -2483.89 iterations 4
# Cbc0038I Pass   7: suminf.    0.05004 (3) obj. -2483.89 iterations 6
# Cbc0038I Solution found of -2484
# Cbc0038I Cleaned solution of -2484
# Cbc0038I Before mini branch and bound, 462 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 26 rows 471 columns, reduced to 4 rows 8 columns
# Cbc0038I Mini branch and bound improved solution from -2484 to -2485 (0.01 seconds)
# Cbc0038I Round again with cutoff of -2487.17
# Cbc0038I Reduced cost fixing fixed 455 variables on major pass 3
# Cbc0038I Pass   8: suminf.    0.08771 (2) obj. -2487.17 iterations 0
# Cbc0038I Pass   9: suminf.    0.16667 (2) obj. -2491.83 iterations 4
# Cbc0038I Pass  10: suminf.    0.91802 (4) obj. -2487.17 iterations 2
# Cbc0038I Pass  11: suminf.    0.49449 (2) obj. -2487.17 iterations 6
# Cbc0038I Pass  12: suminf.    0.49449 (2) obj. -2487.17 iterations 3
# Cbc0038I Pass  13: suminf.    0.50000 (2) obj. -2487.5 iterations 5
# Cbc0038I Pass  14: suminf.    0.68146 (3) obj. -2487.17 iterations 8
# Cbc0038I Pass  15: suminf.    0.68146 (3) obj. -2487.17 iterations 1
# Cbc0038I Pass  16: suminf.    0.25000 (2) obj. -2491.88 iterations 6
# Cbc0038I Pass  17: suminf.    0.08771 (2) obj. -2487.17 iterations 4
# Cbc0038I Pass  18: suminf.    0.16667 (2) obj. -2491.83 iterations 4
# Cbc0038I Pass  19: suminf.    0.13101 (2) obj. -2487.17 iterations 4
# Cbc0038I Pass  20: suminf.    0.08771 (2) obj. -2487.17 iterations 3
# Cbc0038I Pass  21: suminf.    0.29110 (2) obj. -2487.17 iterations 4
# Cbc0038I Pass  22: suminf.    0.29110 (2) obj. -2487.17 iterations 0
# Cbc0038I Pass  23: suminf.    0.33333 (2) obj. -2489.67 iterations 3
# Cbc0038I Pass  24: suminf.    1.05796 (4) obj. -2487.17 iterations 5
# Cbc0038I Pass  25: suminf.    0.89074 (4) obj. -2487.17 iterations 1
# Cbc0038I Pass  26: suminf.    0.89074 (4) obj. -2487.17 iterations 1
# Cbc0038I Pass  27: suminf.    0.89074 (4) obj. -2487.17 iterations 1
# Cbc0038I Pass  28: suminf.    1.05796 (4) obj. -2487.17 iterations 1
# Cbc0038I Pass  29: suminf.    1.00000 (3) obj. -2487.17 iterations 6
# Cbc0038I Pass  30: suminf.    0.48544 (2) obj. -2487.17 iterations 2
# Cbc0038I Pass  31: suminf.    0.31958 (2) obj. -2487.17 iterations 2
# Cbc0038I Pass  32: suminf.    0.33333 (2) obj. -2489.67 iterations 3
# Cbc0038I Pass  33: suminf.    0.29110 (2) obj. -2487.17 iterations 3
# Cbc0038I Pass  34: suminf.    0.08771 (2) obj. -2487.17 iterations 2
# Cbc0038I Pass  35: suminf.    0.08771 (2) obj. -2487.17 iterations 1
# Cbc0038I Pass  36: suminf.    0.16667 (2) obj. -2491.83 iterations 4
# Cbc0038I Pass  37: suminf.    0.93324 (4) obj. -2487.17 iterations 4
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 459 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 26 rows 471 columns, reduced to 5 rows 11 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -2485 - took 0.02 seconds
# Cbc0012I Integer solution of -2485 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 26 rows 471 columns, reduced to 2 rows 5 columns
# Cbc0031I 4 added rows had average density of 8.5
# Cbc0013I At root node, 14 cuts changed objective from -2491.875 to -2485.5213 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 4 row cuts average 6.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 10.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 15 row cuts average 10.5 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -2485, took 12 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 438 variables fixed on reduced cost
# Cuts at root node changed objective from -2491.88 to -2485.52
# Probing was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 3 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 3 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 3 times and created 15 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2485.00000000
# Enumerated nodes:               0
# Total iterations:               12
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.02

# %%
# The status of the solution is printed to the screen
print("Status:", LpStatus[prob.status])
# Out:
# Status: Optimal

# %%
selection = {}
for v in prob.variables():
    index = int(v.name.split("_")[1])
    selection[index] = v.varValue
    # print(v.name, "=", v.varValue)

# %%
data['integer_programming'] = 0.0
for i in selection:
    data.loc[i, 'integer_programming'] = selection[i]

# %%
XI = data[data['integer_programming'] == 1.0]
TOTAL_POINTS = XI['total_points'].sum()
TOTAL_COST = XI['now_cost'].sum()
TOTAL_PLAYERS = XI.shape[0]
print("Total points:{}, cost:£{}, and with players:{}".format(TOTAL_POINTS, TOTAL_COST, TOTAL_PLAYERS))
# Out:
# Total points:2485, cost:£1000, and with players:15

# %%
XI[['first_name', 'second_name', 'element_type', 'team_name', 'total_points', 'now_cost']] \
    .sort_values(by=['team_name'], ascending=False) \
    .reset_index(drop=True)
# Out:
#    first_name                second_name element_type    team_name  \
# 0        José             Malheiro de Sá           GK       Wolves
# 1     Michail                    Antonio          FWD     West Ham
# 2      Jarrod                      Bowen          MID     West Ham
# 3       James                Ward-Prowse          MID  Southampton
# 4        João                    Cancelo          DEF     Man City
# 5    Bernardo  Veiga de Carvalho e Silva          MID     Man City
# 6      Virgil                   van Dijk          DEF    Liverpool
# 7     Alisson              Ramses Becker           GK    Liverpool
# 8       Trent           Alexander-Arnold          DEF    Liverpool
# 9       James                   Maddison          MID    Leicester
# 10       Ivan                      Toney          FWD    Brentford
# 11      Bryan                     Mbeumo          FWD    Brentford
# 12      Matty                       Cash          DEF  Aston Villa
# 13     Bukayo                       Saka          MID      Arsenal
# 14    Gabriel       dos Santos Magalhães          DEF      Arsenal
#
#     total_points  now_cost
# 0            146        50
# 1            140        75
# 2            206        85
# 3            159        65
# 4            201        70
# 5            155        70
# 6            183        65
# 7            176        55
# 8            208        75
# 9            181        80
# 10           139        70
# 11           119        60
# 12           147        50
# 13           179        80
# 14           146        50
